# %%
import json
import ast
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from zipfile import ZipFile

# %%
data = pd.read_csv('./data/test.csv').head(1000)

# %%
data = data[['TAXI_ID', 'POLYLINE']]

# %%
print('Total Path Trail Records used', len(data))
# Out:
# Total Path Trail Records used 1000

# %%
taxi_id = np.unique(data['TAXI_ID'])

# %%
print('Total People', len(taxi_id))
# Out:
# Total People 309

# %%
coordinates = {}
trips = np.array(data)
for i in range(len(trips)):
    point = trips[i]
    keys = list(coordinates.keys())
    if point[0] in keys:
        appended_coordinate = ast.literal_eval(point[1]) + coordinates[point[0]]
        coordinates[point[0]] = appended_coordinate
    else:
        coordinates[point[0]] = ast.literal_eval(point[1])

# %%
taxi_records = [[key, value, 0] for key, value in coordinates.items()]

# %%
coronavirus_cases_count = 5
coronavirus_cases = random.sample(range(1, len(taxi_records)), coronavirus_cases_count) 
random_records = [taxi_records[i][0] for i in coronavirus_cases]

# %%
random_records
# Out:
# [20000473, 20000271, 20000338, 20000651, 20000423]

# %%
from math import sin, cos, sqrt, atan2, radians
R = 6373.0

def calculate_distance(lat2, lon2, lat1, lon1):
    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = (sin(dlat/2))**2 + cos(lat1) * cos(lat2) * (sin(dlon/2))**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = R * c
    return(abs(distance))

# %%
threshold = 0.010

def check_if_contact(lat2, lon2, lat1, lon1):
    calculated_value = calculate_distance(lat1, lon1, lat2, lon2)
    if(calculated_value<=threshold):
        return True
    else:
        return False

# %%
lat1 = 52.2296756
lon1 = 21.0122287
lat2 = 52.2307756
lon2 = 21.0122287
check_if_contact(lat1, lon1, lat2, lon2)
# Out:
# False

# %%
distances = []
for i in taxi_records:
    person_travel_history = i[1]
    max_distance = 0
    for j in range(len(person_travel_history)-1):
        one = person_travel_history[j]
        two = person_travel_history[j+1]
        flag = calculate_distance(one[0], one[1], two[0], two[1])
        if(flag > max_distance):
            max_distance = flag
    distances.append(max_distance)
print('Max distance between any two coordinates', max(distances))
# Out:
# Max distance between any two coordinates 17.43246474762607

# %%
def calculate_total_encounters(history_one, history_two):
    count = 0
    for i in history_one:
        for j in history_two:
            if(check_if_contact(i[0], i[1], j[0], j[1])):
                count +=1 
    return count

# %%
chances = []
for i in taxi_records:
    chance = 0
    if i[0] not in random_records:
        person_travel_history = i[1]
        for coronavirus_case in coronavirus_cases:
            coronavirus_patient_travel_history = taxi_records[coronavirus_case][1]
            chance += calculate_total_encounters(person_travel_history, coronavirus_patient_travel_history)
    chances.append(chance)
    print(i[0], chance)
# Out:
# 20000589 1
# 20000596 12
# 20000320 27
# 20000520 22
# 20000337 40
# 20000231 6
# 20000456 3
# 20000011 13
# 20000403 14
# 20000233 18
# 20000571 36
# 20000497 6
# 20000570 4
# 20000005 29
# 20000089 21
# 20000423 0
# 20000657 2
# 20000309 1
# 20000161 1
# 20000178 26
# 20000235 25
# 20000653 17
# 20000009 27
# 20000648 27
# 20000424 0
# 20000010 5
# 20000372 15
# 20000686 10
# 20000435 115
# 20000154 15
# 20000060 0
# 20000167 5
# 20000503 6
# 20000621 19
# 20000463 2
# 20000612 8
# 20000360 7
# 20000574 8
# 20000173 5
# 20000560 6
# 20000492 9
# 20000112 11
# 20000305 6
# 20000004 10
# 20000620 12
# 20000671 7
# 20000341 13
# 20000015 7
# 20000307 60
# 20000171 1
# 20000201 9
# 20000007 23
# 20000199 23
# 20000611 0
# 20000398 47
# 20000067 3
# 20000569 4
# 20000473 0
# 20000367 26
# 20000672 4
# 20000190 56
# 20000600 13
# 20000496 74
# 20000013 10
# 20000454 23
# 20000534 19
# 20000195 2
# 20000406 10
# 20000325 15
# 20000101 33
# 20000632 4
# 20000308 11
# 20000333 5
# 20000481 38
# 20000486 5
# 20000450 32
# 20000545 3
# 20000665 19
# 20000012 7
# 20000688 0
# 20000540 16
# 20000436 5
# 20000517 40
# 20000153 67
# 20000458 4
# 20000577 11
# 20000105 1
# 20000128 11
# 20000616 0
# 20000477 1
# 20000197 2
# 20000476 7
# 20000480 4
# 20000451 9
# 20000663 23
# 20000386 5
# 20000561 5
# 20000472 6
# 20000280 0
# 20000565 2
# 20000432 2
# 20000329 5
# 20000073 6
# 20000397 11
# 20000285 5
# 20000286 29
# 20000024 15
# 20000239 9
# 20000578 4
# 20000514 32
# 20000152 6
# 20000515 9
# 20000247 20
# 20000344 5
# 20000184 2
# 20000502 9
# 20000400 4
# 20000256 11
# 20000625 3
# 20000196 2
# 20000331 15
# 20000678 34
# 20000901 17
# 20000421 7
# 20000229 11
# 20000381 2
# 20000086 37
# 20000539 10
# 20000242 5
# 20000662 3
# 20000279 2
# 20000076 5
# 20000351 4
# 20000529 24
# 20000042 0
# 20000408 2
# 20000674 12
# 20000304 6
# 20000071 0
# 20000038 2
# 20000137 5
# 20000618 0
# 20000179 3
# 20000120 0
# 20000166 3
# 20000151 8
# 20000434 70
# 20000549 77
# 20000484 2
# 20000075 5
# 20000542 5
# 20000391 7
# 20000131 4
# 20000346 5
# 20000296 1
# 20000058 2
# 20000429 0
# 20000268 6
# 20000051 4
# 20000623 1
# 20000021 5
# 20000046 0
# 20000359 6
# 20000470 8
# 20000114 2
# 20000188 0
# 20000026 4
# 20000077 5
# 20000499 13
# 20000180 3
# 20000409 17
# 20000562 39
# 20000651 0
# 20000669 5
# 20000607 2
# 20000049 60
# 20000272 6
# 20000189 4
# 20000455 13
# 20000144 1
# 20000100 3
# 20000576 13
# 20000554 5
# 20000281 5
# 20000068 1
# 20000050 1
# 20000039 11
# 20000186 4
# 20000687 1
# 20000104 2
# 20000460 1
# 20000446 0
# 20000174 4
# 20000255 0
# 20000065 2
# 20000257 3
# 20000192 0
# 20000507 1
# 20000617 15
# 20000664 7
# 20000027 6
# 20000267 0
# 20000319 7
# 20000380 3
# 20000251 16
# 20000163 1
# 20000682 1
# 20000361 3
# 20000138 8
# 20000495 2
# 20000207 12
# 20000349 2
# 20000684 3
# 20000525 0
# 20000045 0
# 20000633 10
# 20000269 0
# 20000640 12
# 20000258 11
# 20000142 9
# 20000680 1
# 20000116 8
# 20000001 1
# 20000254 4
# 20000384 3
# 20000377 0
# 20000626 0
# 20000294 3
# 20000692 5
# 20000030 11
# 20000579 5
# 20000249 3
# 20000440 2
# 20000271 0
# 20000057 3
# 20000675 0
# 20000588 20
# 20000363 2
# 20000099 2
# 20000326 0
# 20000148 0
# 20000546 0
# 20000230 1
# 20000113 12
# 20000557 2
# 20000376 2
# 20000126 0
# 20000006 1
# 20000288 0
# 20000311 5
# 20000598 2
# 20000352 21
# 20000111 1
# 20000222 0
# 20000085 35
# 20000518 1
# 20000443 6
# 20000330 2
# 20000508 7
# 20000226 3
# 20000370 1
# 20000602 1
# 20000387 4
# 20000353 0
# 20000129 4
# 20000524 2
# 20000048 2
# 20000649 2
# 20000468 0
# 20000467 0
# 20000245 80
# 20000123 1
# 20000601 10
# 20000093 3
# 20000031 0
# 20000487 1
# 20000261 12
# 20000676 0
# 20000431 0
# 20000605 0
# 20000107 3
# 20000047 0
# 20000215 2
# 20000159 3
# 20000156 4
# 20000338 0
# 20000289 0
# 20000410 0
# 20000198 0
# 20000685 0
# 20000074 4
# 20000516 0
# 20000453 0
# 20000604 0
# 20000345 10
# 20000697 0
# 20000315 1
# 20000541 1
# 20000158 1
# 20000136 2
# 20000693 0
# 20000094 0
# 20000014 1
# 20000022 8
# 20000535 0
# 20000054 2
# 20000108 0
# 20000118 0
# 20000328 2

# %%
total_chance_record = []
for i in range(len(taxi_records)):
    taxi_record = taxi_records[i]
    record = [
        taxi_record[0], # taxi_id
        taxi_record[1], # path or trail
        chances[i] # total chances
    ]
    total_chance_record.append(record)

# %%
pd.DataFrame(total_chance_record)
# Out:
#             0                                                  1    2
# 0    20000589  [[-8.649342, 41.154102], [-8.649936, 41.154201...    1
# 1    20000596  [[-8.644077, 41.158845], [-8.644023, 41.158926...   12
# 2    20000320  [[-8.606601, 41.147955], [-8.606457, 41.14791]...   27
# 3    20000520  [[-8.642142, 41.164992], [-8.642151, 41.165037...   22
# 4    20000337  [[-8.660592, 41.158251], [-8.660205, 41.159169...   40
# 5    20000231  [[-8.646642, 41.175711], [-8.647434, 41.17626]...    6
# 6    20000456  [[-8.57952, 41.145948], [-8.580942, 41.145039]...    3
# 7    20000011  [[-8.630433, 41.154831], [-8.631, 41.154381], ...   13
# 8    20000403  [[-8.606484, 41.144625], [-8.606574, 41.144661...   14
# 9    20000233  [[-8.61984, 41.148036], [-8.61984, 41.148036],...   18
# 10   20000571  [[-8.587188, 41.146533], [-8.587143, 41.146515...   36
# 11   20000497  [[-8.650134, 41.159043], [-8.650143, 41.159475...    6
# 12   20000570  [[-8.613297, 41.154372], [-8.613279, 41.154363...    4
# 13   20000005  [[-8.623197, 41.158251], [-8.623098, 41.158206...   29
# 14   20000089  [[-8.619867, 41.148045], [-8.619849, 41.148027...   21
# 15   20000423  [[-8.635482, 41.149593], [-8.635059, 41.149584...    0
# 16   20000657  [[-8.68239, 41.160672], [-8.683092, 41.160456]...    2
# 17   20000309  [[-8.60418, 41.160969], [-8.603874, 41.1615], ...    1
# 18   20000161  [[-8.639883, 41.159736], [-8.639901, 41.159772...    1
# 19   20000178  [[-8.654769, 41.173515], [-8.654778, 41.173497...   26
# 20   20000235  [[-8.585658, 41.148531], [-8.585658, 41.148549...   25
# 21   20000653  [[-8.628399, 41.15772], [-8.630748, 41.154444]...   17
# 22   20000009  [[-8.585613, 41.148576], [-8.585703, 41.148729...   27
# 23   20000648  [[-8.619795, 41.148], [-8.619993, 41.147784], ...   27
# 24   20000424  [[-8.639838, 41.159799], [-8.639901, 41.159772...    0
# 25   20000010  [[-8.601885, 41.181777], [-8.601903, 41.181795...    5
# 26   20000372  [[-8.649414, 41.154336], [-8.650143, 41.154237...   15
# 27   20000686  [[-8.610129, 41.146317], [-8.610102, 41.146317...   10
# 28   20000435  [[-8.611677, 41.149062], [-8.611623, 41.149062...  115
# 29   20000154  [[-8.645292, 41.166189], [-8.64504, 41.166171]...   15
# ..        ...                                                ...  ...
# 279  20000605  [[-8.597997, 41.162382], [-8.598141, 41.16195]...    0
# 280  20000107  [[-8.574759, 41.142717], [-8.574723, 41.14296]...    3
# 281  20000047  [[-8.657361, 41.170338], [-8.657334, 41.170311...    0
# 282  20000215  [[-8.610849, 41.145597], [-8.610759, 41.145813...    2
# 283  20000159  [[-8.610732, 41.145705], [-8.610732, 41.145723...    3
# 284  20000156  [[-8.582517, 41.180535], [-8.582481, 41.180499...    4
# 285  20000338  [[-8.647542, 41.151087], [-8.647434, 41.150853...    0
# 286  20000289  [[-8.646588, 41.165757], [-8.645184, 41.165523...    0
# 287  20000410  [[-8.649603, 41.16726], [-8.649585, 41.167251]...    0
# 288  20000198  [[-8.566263, 41.153598], [-8.566272, 41.153598...    0
# 289  20000685  [[-8.653482, 41.158278], [-8.653482, 41.158287...    0
# 290  20000074  [[-8.639928, 41.159592], [-8.640225, 41.159691...    4
# 291  20000516  [[-8.614395, 41.142096], [-8.614386, 41.142087...    0
# 292  20000453  [[-8.592372, 41.157333], [-8.592372, 41.157333...    0
# 293  20000604  [[-8.609436, 41.151357], [-8.609382, 41.151402...    0
# 294  20000345  [[-8.585604, 41.14854], [-8.585712, 41.148684]...   10
# 295  20000697  [[-8.605638, 41.153697], [-8.60706, 41.153625]...    0
# 296  20000315  [[-8.606547, 41.144661], [-8.606547, 41.144643...    1
# 297  20000541  [[-8.585631, 41.148522], [-8.585712, 41.148666...    1
# 298  20000158  [[-8.569728, 41.166072], [-8.569332, 41.16618]...    1
# 299  20000136  [[-8.628813, 41.161041], [-8.628723, 41.160996...    2
# 300  20000693  [[-8.660295, 41.150052], [-8.660304, 41.15007]...    0
# 301  20000094  [[-8.652789, 41.156127], [-8.652834, 41.156082...    0
# 302  20000014  [[-8.582787, 41.181192], [-8.581851, 41.181876...    1
# 303  20000022  [[-8.589357, 41.163264], [-8.589429, 41.163255...    8
# 304  20000535  [[-8.604126, 41.161077], [-8.603964, 41.161464...    0
# 305  20000054  [[-8.606412, 41.144706], [-8.606727, 41.144778...    2
# 306  20000108  [[-8.653077, 41.168502], [-8.653329, 41.168628...    0
# 307  20000118  [[-8.57475, 41.142699], [-8.574759, 41.142708]...    0
# 308  20000328  [[-8.585604, 41.148504], [-8.585694, 41.148693...    2
#
# [309 rows x 3 columns]

# %%
total_encounter = pd.DataFrame(total_chance_record)
total_encounter = total_encounter.sort_values(by=2, ascending=False)
total_encounter.to_csv('./data/chances.csv')
